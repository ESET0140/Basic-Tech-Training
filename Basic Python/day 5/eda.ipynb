# %%
import pandas as pd

# %%
import numpy as np

# %%
data = pd.read_csv("datasets.csv")

# %% [markdown]
# descriptive data analysis

# %% [markdown]
# first five data

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#            datasetName                                            about  \
# 0   Microbiome Project                American Gut (Microbiome Project)
# 1                GloBI               Global Biotic Interactions (GloBI)
# 2       Global Climate                   Global Climate Data Since 1929
# 3      CommonCraw 2012              3.5B Web Pages from CommonCraw 2012
# 4    Indiana Webclicks  53.5B Web clicks of 100K users in Indiana Univ.
# ..                 ...                                              ...
# 56      ClueWeb12 FACC                                   ClueWeb12 FACC
# 57       Google Ngrams                      Google Books Ngrams (2.2TB)
# 58          EDRM Enron      EDRM Enron EMail of 151 users, hosted on S3
# 59             GetGlue                  GetGlue - users rating TV shows
# 60      Twitter RepLab    Twitter Data for Online Reputation Management
#
#                                                  link       categoryName  \
# ...

# %% [markdown]
# last 5 data

# %%
df.tail()
# Out:
#        datasetName                                          about  \
# 56  ClueWeb12 FACC                                 ClueWeb12 FACC
# 57   Google Ngrams                    Google Books Ngrams (2.2TB)
# 58      EDRM Enron    EDRM Enron EMail of 151 users, hosted on S3
# 59         GetGlue                GetGlue - users rating TV shows
# 60  Twitter RepLab  Twitter Data for Online Reputation Management
#
#                                                  link      categoryName  \
# 56           http://lemurproject.org/clueweb12/FACC1/  Natural Language
# 57  https://aws.amazon.com/datasets/google-books-n...  Natural Language
# 58  https://aws.amazon.com/datasets/enron-email-data/   Social Networks
# 59  http://getglue-data.s3.amazonaws.com/getglue_s...   Social Networks
# 60                     http://nlp.uned.es/replab2013/   Social Networks
#
#      cloud  vintage
# 56     NaN   2012.0
# 57  Amazon      NaN
# 58  Amazon      NaN
# 59     NaN      NaN
# 60     NaN   2013.0

# %%
df.head()
# Out:
#           datasetName                                            about  \
# 0  Microbiome Project                American Gut (Microbiome Project)
# 1               GloBI               Global Biotic Interactions (GloBI)
# 2      Global Climate                   Global Climate Data Since 1929
# 3     CommonCraw 2012              3.5B Web Pages from CommonCraw 2012
# 4   Indiana Webclicks  53.5B Web clicks of 100K users in Indiana Univ.
#
#                                                 link       categoryName  \
# 0            https://github.com/biocore/American-Gut            Biology
# 1  https://github.com/jhpoelen/eol-globi-data/wik...            Biology
# 2                     http://en.tutiempo.net/climate    Climate/Weather
# 3  http://www.bigdatanews.com/profiles/blogs/big-...  Computer Networks
# 4  http://cnets.indiana.edu/groups/nan/webtraffic...  Computer Networks
#
#     cloud  vintage
# 0  GitHub      NaN
# 1  GitHub      NaN
# 2     NaN   1929.0
# 3     NaN   2012.0
# ...

# %%
data.shape
# Out:
# (61, 6)

# %%
df.dtypes
# Out:
# datasetName      object
# about            object
# link             object
# categoryName     object
# cloud            object
# vintage         float64
# dtype: object

# %%
df.info
# Out:
# <bound method DataFrame.info of            datasetName                                            about  \
# 0   Microbiome Project                American Gut (Microbiome Project)
# 1                GloBI               Global Biotic Interactions (GloBI)
# 2       Global Climate                   Global Climate Data Since 1929
# 3      CommonCraw 2012              3.5B Web Pages from CommonCraw 2012
# 4    Indiana Webclicks  53.5B Web clicks of 100K users in Indiana Univ.
# ..                 ...                                              ...
# 56      ClueWeb12 FACC                                   ClueWeb12 FACC
# 57       Google Ngrams                      Google Books Ngrams (2.2TB)
# 58          EDRM Enron      EDRM Enron EMail of 151 users, hosted on S3
# 59             GetGlue                  GetGlue - users rating TV shows
# 60      Twitter RepLab    Twitter Data for Online Reputation Management
#
# ...

# %% [markdown]
# drop method to remove coloumns which are not useful

# %%
new_d = df.drop("vintage", axis='columns')

# %%
new_d
# Out:
#            datasetName                                            about  \
# 0   Microbiome Project                American Gut (Microbiome Project)
# 1                GloBI               Global Biotic Interactions (GloBI)
# 2       Global Climate                   Global Climate Data Since 1929
# 3      CommonCraw 2012              3.5B Web Pages from CommonCraw 2012
# 4    Indiana Webclicks  53.5B Web clicks of 100K users in Indiana Univ.
# ..                 ...                                              ...
# 56      ClueWeb12 FACC                                   ClueWeb12 FACC
# 57       Google Ngrams                      Google Books Ngrams (2.2TB)
# 58          EDRM Enron      EDRM Enron EMail of 151 users, hosted on S3
# 59             GetGlue                  GetGlue - users rating TV shows
# 60      Twitter RepLab    Twitter Data for Online Reputation Management
#
#                                                  link       categoryName  \
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of            datasetName                                            about  \
# 0   Microbiome Project                American Gut (Microbiome Project)
# 1                GloBI               Global Biotic Interactions (GloBI)
# 2       Global Climate                   Global Climate Data Since 1929
# 3      CommonCraw 2012              3.5B Web Pages from CommonCraw 2012
# 4    Indiana Webclicks  53.5B Web clicks of 100K users in Indiana Univ.
# ..                 ...                                              ...
# 56      ClueWeb12 FACC                                   ClueWeb12 FACC
# 57       Google Ngrams                      Google Books Ngrams (2.2TB)
# 58          EDRM Enron      EDRM Enron EMail of 151 users, hosted on S3
# 59             GetGlue                  GetGlue - users rating TV shows
# 60      Twitter RepLab    Twitter Data for Online Reputation Management
#
# ...

# %% [markdown]
# rename coloumn

# %%
df = df.rename(columns={'about':'info'})

# %%
df.head()
# Out:
#           datasetName                                             info  \
# 0  Microbiome Project                American Gut (Microbiome Project)
# 1               GloBI               Global Biotic Interactions (GloBI)
# 2      Global Climate                   Global Climate Data Since 1929
# 3     CommonCraw 2012              3.5B Web Pages from CommonCraw 2012
# 4   Indiana Webclicks  53.5B Web clicks of 100K users in Indiana Univ.
#
#                                                 link       categoryName  \
# 0            https://github.com/biocore/American-Gut            Biology
# 1  https://github.com/jhpoelen/eol-globi-data/wik...            Biology
# 2                     http://en.tutiempo.net/climate    Climate/Weather
# 3  http://www.bigdatanews.com/profiles/blogs/big-...  Computer Networks
# 4  http://cnets.indiana.edu/groups/nan/webtraffic...  Computer Networks
#
#     cloud  vintage
# 0  GitHub      NaN
# 1  GitHub      NaN
# 2     NaN   1929.0
# 3     NaN   2012.0
# ...

# %%
duplicate_df_row = df[df.duplicated()]

# %%
duplicate_df_row
# Out:
# Empty DataFrame
# Columns: [datasetName, info, link, categoryName, cloud, vintage]
# Index: []

# %% [markdown]
# drop duplicate values

# %%
df= df.drop_duplicates()

# %% [markdown]
# is Null to check null values

# %%
df.isnull()
# Out:
#     datasetName   info   link  categoryName  cloud  vintage
# 0         False  False  False         False  False     True
# 1         False  False  False         False  False     True
# 2         False  False  False         False   True    False
# 3         False  False  False         False   True    False
# 4         False  False  False         False   True     True
# ..          ...    ...    ...           ...    ...      ...
# 56        False  False  False         False   True    False
# 57        False  False  False         False  False     True
# 58        False  False  False         False  False     True
# 59        False  False  False         False   True     True
# 60        False  False  False         False   True    False
#
# [61 rows x 6 columns]

# %% [markdown]
# total null values by adding .sum() to check how many nulls are there

# %%
df.isnull().sum()
# Out:
# datasetName      0
# info             0
# link             0
# categoryName     0
# cloud           37
# vintage         30
# dtype: int64

# %% [markdown]
# remove rows with word "na"

# %%
df = df.dropna()

# %%
df.count()
# Out:
# datasetName     2
# info            2
# link            2
# categoryName    2
# cloud           2
# vintage         2
# dtype: int64

# %%
df
# Out:
#             datasetName                                             info  \
# 32  FBI Hate Crime 2013            FBI Hate Crime 2013 - aggregated data
# 41             NYC Uber  NYC Uber trip data April 2014 to September 2014
#
#                                                  link     categoryName  \
# 32  https://github.com/emorisse/FBI-Hate-Crime-Sta...  Social Sciences
# 41  https://github.com/fivethirtyeight/uber-tlc-fo...   Transportation
#
#      cloud  vintage
# 32  GitHub   2013.0
# 41  GitHub   2014.0
